# %% [markdown]
# ## Image to Pencil Sketch

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage
import cv2
from skimage import io
from PIL import Image

# %% [markdown]
# ### Reading Image

# %%
img=cv2.imread(r"C:\Users\vamsh\OneDrive\Pictures\photo-prof.jpg")
img
# Out:
# array([[[135, 134, 144],
#         [136, 135, 145],
#         [136, 135, 145],
#         ...,
#         [175, 177, 177],
#         [175, 177, 177],
#         [174, 176, 176]],
#
#        [[110, 109, 119],
#         [110, 109, 118],
#         [110, 109, 119],
#         ...,
#         [184, 186, 186],
#         [183, 185, 185],
#         [183, 185, 185]],
#
#        [[110, 109, 118],
#         [110, 110, 116],
#         [110, 109, 118],
#         ...,
#         [195, 197, 197],
#         [195, 197, 197],
#         [194, 196, 196]],
#
#        ...,
#
#        [[133, 122, 125],
#         [ 79,  63,  64],
#         [ 59,  32,  28],
#         ...,
#         [115,  92,  84],
#         [114,  90,  84],
#         [113,  90,  82]],
#
#        [[132, 123, 126],
#         [ 77,  63,  64],
#         [ 57,  32,  28],
#         ...,
#         [128, 110, 103],
#         [128, 112, 106],
#         [128, 112, 105]],
#
#        [[132, 123, 126],
#         [ 77,  63,  64],
#         [ 57,  32,  30],
# ...

# %%
plt.imshow(img)

# %% [markdown]
# ### Converting Img to Gray scale

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray_img
# Out:
# array([[137, 138, 138, ..., 177, 177, 176],
#        [112, 112, 112, ..., 186, 185, 185],
#        [112, 112, 112, ..., 197, 197, 196],
#        ...,
#        [124,  65,  34, ...,  92,  91,  90],
#        [125,  65,  34, ..., 110, 112, 112],
#        [125,  65,  34, ..., 126, 128, 128]], dtype=uint8)

# %%
plt.imshow(gray_img)

# %%
import cv2

# Assuming 'image' is your image
channels = cv2.split(gray_img)

if len(channels) == 1:
    print("Image is in grayscale")
elif len(channels) == 3:
    print("Image is in RGB")
elif len(channels) == 4:
    print("Image is in RGBA")
else:
    print("Image has an unexpected number of channels")
# Out:
# Image is in grayscale

# %% [markdown]
# ### Invert the Grayscale image

# %% [raw]
# Dark areas in the input area becomes light and light area becomes dark

# %%
inverted_img=255-gray_img
plt.imshow(inverted_img)

# %% [markdown]
# ### Blurred image using Gaussian function

# %%
blurred=cv2.GaussianBlur(inverted_img,(25,25),0)
plt.imshow(blurred)

# %% [markdown]
# ### Inverted Blurred Image

# %%
Inverted_blurr=255-blurred
plt.imshow(Inverted_blurr)

# %% [markdown]
# ### Divide the gray image by inverted Blurred image

# %%
pencil_sketch=cv2.divide(gray_img,Inverted_blurr,scale=256)
plt.imshow(pencil_sketch)

# %%
cv2.imshow('original image',img)
cv2.imshow('Sketch',pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2

def convert_to_pencil_sketch(image_path):
    # Read the image
    img = cv2.imread(image_path)

    # Check if the image is loaded successfully
    if img is None:
        print(f"Error: Unable to load image from {image_path}")
        return

    # Convert the image to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Invert the grayscale image
    inverted_img = 255 - gray_img

    # Apply GaussianBlur to the inverted image
    blurred = cv2.GaussianBlur(inverted_img, (25, 25), 0)

    # Invert the blurred image
    inverted_blur = 255 - blurred

    # Create the pencil sketch by dividing the grayscale image by the inverted blurred image
    pencil_sketch = cv2.divide(gray_img, inverted_blur, scale=256)

    # Display the original and sketch images
    cv2.imshow('Original Image', img)
    cv2.imshow('Pencil Sketch', pencil_sketch)
    cv2.waitKey(0)

# %%
# Call the function with the image path
convert_to_pencil_sketch(r"C:\Users\vamsh\OneDrive\Pictures\WhatsApp Image 2023-07-09 at 09.08.39 ,vamshi image -2.jpg")
